# %% [markdown]
# ###Window Function
# #### window function works on group of rows and returns a single value for each row
#
#
#
# #####WINDOW FUNCTIONS USAGE & SYNTAX	PYSPARK WINDOW FUNCTIONS DESCRIPTION
# ######row_number()                                     : Column	Returns a sequential number starting from 1 within a window partition
# ######rank()                                           : Column	Returns the rank of rows within a window partition, with gaps.
# ######percent_rank()                                   : Column	Returns the percentile rank of rows within a window partition.
# ######dense_rank()                                     : Column	Returns the rank of rows within a window partition without any gaps. Where as Rank() returns rank with gaps.
# ######ntile(n: Int)                                    : Column	Returns the ntile id in a window partition
# ######cume_dist()                                      : Column	Returns the cumulative distribution of values within a window partition
# ######lag(e: Column, offset: Int)                      : Column
# ######lag(columnName: String, offset: Int)             : Column
# ######lag(columnName: String, offset: Int, defaultValue: Any): Column	returns the value that is `offset` rows before the current row, and `null` if there is less than `offset` rows before the current row.
# ######lead(columnName: String, offset: Int): Column
# ######lead(columnName: String, offset: Int): Column
# ######lead(columnName: String, offset: Int, defaultValue: Any): Column	returns the value that is `offset` rows after the current row, and `null` if there is less than `offset` rows after the current row.

# %%
from pyspark.sql.window import Window
from pyspark.sql.functions import desc, rank, dense_rank,col, aggregate, countDistinct
from pyspark.sql.functions import sum as _sum
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %run "../includes/configuration"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_demo = spark.read.option("header",True).parquet(f"{presentation_folderpath}/race_results")
display(df_demo.limit(10))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>race_year</th><th>race_name</th><th>race_date</th><th>circuit_location</th><th>driver_name</th><th>driver_number</th><th>driver_nationality</th><th>team</th><th>grid</th><th>fastest_lap</th><th>race_time</th><th>points</th><th>position</th><th>created_date</th></tr></thead><tbody><tr><td>2018</td><td>Australian Grand Prix</td><td>2018-03-25T05:10:00.000+0000</td><td>Melbourne</td><td>Sergey Sirotkin</td><td>35</td><td>Russian</td><td>Williams</td><td>19</td><td>3</td><td>\N</td><td>0.0</td><td>null</td><td>2021-12-23T06:13:06.418+0000</td></tr><tr><td>2018</td><td>Australian Grand Prix</td><td>2018-03-25T05:10:00.000+0000</td><td>Melbourne</td><td>Marcus Ericsson</td><td>9</td><td>Swedish</td><td>Sauber</td><td>17</td><td>4</td><td>\N</td><td>0.0</td><td>null</td><td>2021-12-23T06:13:06.418+0000</td></tr><tr><td>2018</td><td>Australian Grand Prix</td><td>2018-03-25T05:10:00.000+0000</td><td>Melbourne</td><td>Pierre Gasly</td><td>10</td><td>French</td><td>Toro Rosso</td><td>20</td><td>13</td><td>\N</td><td>0.0</td><td>null</td><td>2021-12-23T06:13:06.418+0000</td></tr><tr><td>2018</td><td>Australian Grand Prix</td><td>2018-03-25T05:10:00.000+0000</td><td>Melbourne</td><td>Kevin Magnussen</td><td>20</td><td>Danish</td><td>Haas F1 Team</td><td>5</td><td>21</td><td>\N</td><td>0.0</td><td>null</td><td>2021-12-23T06:13:06.418+0000</td></tr><tr><td>2018</td><td>Australian Grand Prix</td><td>2018-03-25T05:10:00.000+0000</td><td>Melbourne</td><td>Romain Grosjean</td><td>8</td><td>French</td><td>Haas F1 Team</td><td>6</td><td>23</td><td>\N</td><td>0.0</td><td>null</td><td>2021-12-23T06:13:06.418+0000</td></tr><tr><td>2018</td><td>Australian Grand Prix</td><td>2018-03-25T05:10:00.000+0000</td><td>Melbourne</td><td>Brendon Hartley</td><td>28</td><td>New Zealander</td><td>Toro Rosso</td><td>16</td><td>57</td><td>\N</td><td>0.0</td><td>15</td><td>2021-12-23T06:13:06.418+0000</td></tr><tr><td>2018</td><td>Australian Grand Prix</td><td>2018-03-25T05:10:00.000+0000</td><td>Melbourne</td><td>Lance Stroll</td><td>18</td><td>Canadian</td><td>Williams</td><td>13</td><td>55</td><td>+1:18.288</td><td>0.0</td><td>14</td><td>2021-12-23T06:13:06.418+0000</td></tr><tr><td>2018</td><td>Australian Grand Prix</td><td>2018-03-25T05:10:00.000+0000</td><td>Melbourne</td><td>Charles Leclerc</td><td>16</td><td>Monegasque</td><td>Sauber</td><td>18</td><td>56</td><td>+1:15.759</td><td>0.0</td><td>13</td><td>2021-12-23T06:13:06.418+0000</td></tr><tr><td>2018</td><td>Australian Grand Prix</td><td>2018-03-25T05:10:00.000+0000</td><td>Melbourne</td><td>Esteban Ocon</td><td>31</td><td>French</td><td>Force India</td><td>14</td><td>57</td><td>+1:00.278</td><td>0.0</td><td>12</td><td>2021-12-23T06:13:06.418+0000</td></tr><tr><td>2018</td><td>Australian Grand Prix</td><td>2018-03-25T05:10:00.000+0000</td><td>Melbourne</td><td>Sergio Pérez</td><td>11</td><td>Mexican</td><td>Force India</td><td>12</td><td>51</td><td>+46.817</td><td>0.0</td><td>11</td><td>2021-12-23T06:13:06.418+0000</td></tr></tbody></table></div>

# %%
df_demo_grouped = df_demo\
.groupBy("race_year","driver_name")\
.agg(_sum("points").alias("total_points"), countDistinct("race_name").alias("num_races"))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
</td><td>256.0</td><td>21</td><td>3</td></tr><tr><td>2010</td><td>Fernando Alonso</td><td>252.0</td><td>19</td><td>2</td></tr><tr><td>2018</td><td>Kimi Räikkönen</td><td>251.0</td><td>21</td><td>3</td></tr><tr><td>2018</td><td>Max Verstappen</td><td>249.0</td><td>21</td><td>4</td></tr><tr><td>2018</td><td>Valtteri Bottas</td><td>247.0</td><td>21</td><td>5</td></tr><tr><td>2010</td><td>Mark Webber</td><td>242.0</td><td>19</td><td>3</td></tr><tr><td>2013</td><td>Fernando Alonso</td><td>242.0</td><td>19</td><td>2</td></tr><tr><td>2010</td><td>Lewis Hamilton</td><td>240.0</td><td>19</td><td>4</td></tr><tr><td>2019</td><td>Sebastian Vettel</td><td>240.0</td><td>21</td><td>5</td></tr><tr><td>2014</td><td>Daniel Ricciardo</td><td>238.0</td><td>19</td><td>3</td></tr><tr><td>2011</td><td>Lewis Hamilton</td><td>227.0</td><td>19</td><td>5</td></tr><tr><td>2020</td><td>Valtteri Bottas</td><td>223.0</td><td>17</td><td>2</td></tr><tr><td>2010</td><td>Jenson Button</td><td>214.0</td><td>19</td><td>5</td></tr><tr><td>2020</td><td>Max Verstappen</td><td>214.0</td><td>17</td><td>3</td></tr><tr><td>2016</td><td>Sebastian Vettel</td><td>212.0</td><td>21</td><td>4</td></tr><tr><td>2012</td><td>Kimi Räikkönen</td><td>207.0</td><td>20</td><td>3</td></tr><tr><td>2017</td><td>Kimi Räikkönen</td><td>205.0</td><td>20</td><td>4</td></tr><tr><td>2016</td><td>Max Verstappen</td><td>204.0</td><td>21</td><td>5</td></tr><tr><td>2017</td><td>Daniel Ricciardo</td><td>200.0</td><td>20</td><td>5</td></tr><tr><td>2013</td><td>Mark Webber</td><td>199.0</td><td>19</td><td>3</td></tr><tr><td>2012</td><td>Lewis Hamilton</td><td>190.0</td><td>20</td><td>4</td></tr><tr><td>2013</td><td>Lewis Hamilton</td><td>189.0</td><td>19</td><td>4</t ...

# %%
df_rank_exmpl = df_demo_grouped.withColumn("dense_rank",dense_rank().over("total_points"))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">TypeError</span>                                 Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-4045695602290928&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-fg">----&gt; 1</span><span class="ansi-red-fg"> </span>df_rank_exmpl <span class="ansi-blue-fg">=</span> df_demo_grouped<span class="ansi-blue-fg">.</span>withColumn<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#34;dense_rank&#34;</span><span class="ansi-blue-fg">,</span>dense_rank<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">.</span>over<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#34;total_points&#34;</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">)</span>
#
# <span class="ansi-green-fg">/databricks/spark/python/pyspark/sql/column.py</span> in <span class="ansi-cyan-fg">over</span><span class="ansi-blue-fg">(self, window)</span>
# <span class="ansi-green-intense-fg ansi-bold">    907</span>         <span class="ansi-green-fg">from</span> pyspark<span class="ansi-blue-fg">.</span>sql<span class="ansi-blue-fg">.</span>window <span class="ansi-green-fg">import</span> WindowSpec
# <span class="ansi-green-intense-fg ansi-bold">    908</span>         <span class="ansi-green-fg">if</span> <span class="ansi-green-fg">not</span> isinstance<span class="ansi-blue-fg">(</span>window<span class="ansi-blue-fg">,</span> WindowSpec<span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">:</span>
# <span class="ansi-green-fg">--&gt; 909</span><span class="ansi-red-fg">             </span><span class="ansi-green-fg">raise</span> TypeError<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#34;window should be WindowSpec&#34;</span><span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">    910</span>         jc <span class="ansi-blue-fg">=</span> self<span class="ansi-blue-fg">.</span>_jc<span class="ansi-blue-fg">.</span>over<span class="ansi-blue-fg">(</span>window<span class="ansi-blue-fg">.</span>_jspec<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">    911</span>         <span class="ansi-green-fg">return</span> Column<span class="ansi-blue-fg">(</span>jc<span class="ansi-blue-fg">)</span>
#
# <span class="ansi-red-fg">TypeError</span>: window should be WindowSpec</div>
